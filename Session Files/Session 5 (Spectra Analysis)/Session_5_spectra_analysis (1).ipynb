# %% [markdown]
# # Session 5

# %% [markdown]
# In today's session we will learn about how to extract spectra from the MIRI IFU spectral cube, JWST. We will also identify emission lines.
#
# This session will become the base of one of your projects. So take it seriously!!

# %% [markdown]
# ## Spectral Cube

# %% [markdown]
# Unlike image that has 2 spatial axis, this has one spectral axis too. It can be in wavelength,frequency or velocity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# JWST has the following instruments:
#
# 1. NIRCam
# 2. NIRSpec
# 3. MIRI     --> We will use this today!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can read more here: https://jwst-docs.stsci.edu/jwst-mid-infrared-instrument#gsc.tab=0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Make sure to download the -c1006 files because that means it is calibrated. These are level 3 files (_x3d.fits) i.e. science ready. Refer to the session 3 (exploring data archive session) to understand how to use MAST portal.

# %% [markdown]
# # regions

# %% [markdown]
# regions is an in-development coordinated package of Astropy for region handling.
#
# The Regions package provides classes to represent:
#
#     Regions defined using pixel coordinates (e.g., CirclePixelRegion)
#     Regions defined using celestial coordinates, but still in an Euclidean geometry (e.g., CircleSkyRegion)
#     To transform between sky and pixel regions, a world coordinate system object (e.g., astropy.wcs.WCS) is needed.
#
# Regions also provides a unified interface for reading, writing, parsing, and serializing regions data in different formats, including the DS9 Region Format, CRTF (CASA Region Text Format), and FITS Region Binary Table format.
#
# You can read more about it in here:
#
# https://astropy-regions.readthedocs.io/en/stable/shapes.html

# %%
#Region-wise line plotting

# Import necessary libraries
import numpy as np
import warnings
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
from regions import Regions

warnings.filterwarnings("ignore", category=UserWarning, append=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 from astropy.io import fits
#       8 from astropy.wcs import WCS
# ----> 9 from regions import Regions
#      11 warnings.filterwarnings("ignore", category=UserWarning, append=True)
#
# ModuleNotFoundError: No module named 'regions'

# %%
# Define the redshift for NGC 7469
# NGC 7469 is a Seyfert galaxy with a redshift of approximately 0.016268
# This value is used to convert observed wavelengths to rest-frame wavelengths
# The redshift value can be obtained from various astronomical databases like NED (NASA/IPAC Extragalactic Database)

z = 0.016268

reg_path = "region_file.reg" # From DS9 lecture, this is the region file containing the regions of interest
# Read the regions from the DS9 region file
# Make sure to have the regions file in the same directory as this script
regions = Regions.read(reg_path, format='ds9')


file_paths = []

# Only channel 2 for the session
for part in ['short','medium','long']:
        # I have kept them in a subfolder MAST_NGC_7469 for clarity
        # You can change the path as per your directory structure
        # The file names are based on the JWST data release naming convention
        file_paths.append(f'./MAST_NGC_7469/jw01328-c1006_t014_miri_ch{2}-{part}_s3d.fits')

# for ch_num in range(1,5):
#     for part in ['short','medium','long']:
#         file_paths.append(f'./MAST_NGC_7469/jw01328-c1006_t014_miri_ch{ch_num}-{part}_s3d.fits')

print(file_paths)
# Out:
# ['./MAST_NGC_7469/jw01328-c1006_t014_miri_ch2-short_s3d.fits', './MAST_NGC_7469/jw01328-c1006_t014_miri_ch2-medium_s3d.fits', './MAST_NGC_7469/jw01328-c1006_t014_miri_ch2-long_s3d.fits']

# %% [markdown]
# Now we have defined the redshift from NED, made a region file from DS9 and made a list of all the files to iterate over.
#
# We can proceed further and extract the spectra from each of the file and plot the final spectrum from it.

# %%
# Loop over each region
for region in regions:  # For now we are only considering one region. In your project you can loop over all regions
    
    # Initialize lists to store the spectrum and wavelength for all channels

    spectrum_all = []
    spectrum_all_err = []
    wavelength_all = []

    for channel_index, file_path in enumerate(file_paths, start=1):
        
        # Initialize empty lists to store the spectrum and wavelength for this channel
        # This is done to store the spectrum and wavelength for each channel separately
        # This allows us to combine the spectra from all channels later
        spectrum = []
        spectrum_err = []

        # Get the mask for the region
        data = fits.open(file_path)[1].data       # 1 contain the 3D data cube
        data[data < 0] = np.nan
        data_err = fits.open(file_path)[2].data   # 2 contain the error cube

        # Open the FITS file and get the WCS information to make mask of the region
        # Mask means the region of interest in the image - other parts are ignored
        header = fits.open(file_path)[1].header
        wcs = WCS(header)
        mask = region.to_pixel(wcs.celestial).to_mask()  # Convert the region from celestial to pixel coordinates then make a mask
        # Get the shape of the data
        num_channels, ny, nx = data.shape

        # Loop over each channel (wavelength)
        for i in range(num_channels):
            # Extract the 2D image for the current channel
            masked_data = np.array(mask.multiply(data[i, :, :]), dtype=float)
            masked_data_err = np.array(mask.multiply(data_err[i, :, :]), dtype=float)

            avg_intensity = np.nanmean(masked_data)
            avg_intensity_err = np.sqrt(np.nanmean(masked_data_err**2))

            # Handle case where all values are NaN. To avoid RuntimeWarning: Mean of empty slice
            if np.isnan(avg_intensity):
                avg_intensity = 0
            if np.isnan(avg_intensity_err):
                avg_intensity_err = 0

            spectrum.append(avg_intensity)
            spectrum_err.append(avg_intensity_err)

        # Set up the wavelength axis
        n_wavelengths = data.shape[0]  # Number of wavelengths in the channel

        # Extract the WCS information from the header to get the wavelength values
        # CRVAL3, CDELT3, and CRPIX3 are WCS keywords that define the wavelength axis
    
        crval3 = header['CRVAL3']   # CRVAL3 is the reference value of the wavelength axis
        cdelt3 = header['CDELT3']   # CDELT3 is the increment in the wavelength axis
        crpix3 = header['CRPIX3']   # CRPIX3 is the reference pixel of the wavelength axis

        wavelength = (np.arange(n_wavelengths) - (crpix3 - 1)) * cdelt3 + crval3
        wavelength = wavelength / (1 + z) # Convert to rest-frame wavelength
        
        # Append the results for this channel to the overall lists
        # This is done to combine the spectra from all channels into one list
        # This allows us to plot the spectrum across all channels in one go
        # The wavelength and spectrum lists will have the same length
        
        wavelength_all.extend(wavelength)
        spectrum_all.extend(spectrum)
        spectrum_all_err.extend(spectrum_err)

        # Now you can add it to a dataframe. Explore pandas for this.
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-04T03:48:44.191' from MJD-BEG.
# Set DATE-AVG to '2022-07-04T03:54:53.948' from MJD-AVG.
# Set DATE-END to '2022-07-04T04:01:02.328' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -72.559129 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -38.282938 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1737445736.637 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-04T04:05:31.550' from MJD-BEG.
# Set DATE-AVG to '2022-07-04T04:11:31.595' from MJD-AVG.
# Set DATE-END to '2022-07-04T04:17:33.047' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -72.557468 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -38.283459 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1737461184.326 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-04T04:22:24.413' from MJD-BEG.
# Set DATE-AVG to '2022-07-04T04:28:21.738' from MJD-AVG.
# Set DATE-END to '2022-07-04T04:34:17.654' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -72.555797 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -38.283980 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1737476718.880 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
plt.figure(figsize=(15, 8))
plt.errorbar(wavelength_all, spectrum_all, yerr=spectrum_all_err, color='blue', ecolor='black')
plt.xlabel('Wavelength (microns)')
plt.ylabel('Average Intensity (MJy/sr)')

# Change the x-axis limits to focus on the desired region
# w_start, w_end = 8.95, 9.05
# plt.xlim(w_start, w_end)

# Auto-scale y-axis to the visible range
# plt.ylim(0, 1.1*np.nanmax(spectrum_all[(wavelength_all >= w_start) & (wavelength_all <= w_end)]))
plt.grid(True)
plt.legend()

# %%
# %pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.1.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.41.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from plotly) (24.2)
# Downloading plotly-6.1.2-py3-none-any.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading narwhals-1.41.1-py3-none-any.whl (358 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.41.1 plotly-6.1.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The code below is to plot and interactively view the final spectra. It might be complex so you can treat it as a black box or explore on your own.
#
# Your task here is to fill the spectral features by opening each file in cubeviz. I will give you an example walkthrough.

# %%
import plotly.graph_objects as go
import numpy as np

# Initialize figure with custom size
fig = go.Figure(layout=dict(
    width=800,  # Width in pixels
    height=500,  # Height in pixels
    template='plotly_white'
))

# Add spectrum trace
fig.add_trace(go.Scatter(
    x=wavelength_all,
    y=spectrum_all,
    mode='lines',
    line=dict(color='#1f77b4', width=1.5),
    name='Spectrum',
    hovertemplate='λ: %{x:.3f} μm<br>Intensity: %{y:.2f} MJy/sr<extra></extra>'
))

# Convert list to numpy
spectrum_all = np.array(spectrum_all)
spectrum_all_err = np.array(spectrum_all_err)

# Convert wavelength list to numpy
wavelength_all = np.array(wavelength_all)

# Add error band
fig.add_trace(go.Scatter(
    x=np.concatenate([wavelength_all, wavelength_all[::-1]]),
    y=np.concatenate([spectrum_all + spectrum_all_err, 
                     (spectrum_all - spectrum_all_err)[::-1]]),
    fill='toself',
    fillcolor='rgba(31, 119, 180, 0.2)',
    line=dict(color='rgba(255,255,255,0)'),
    hoverinfo='skip',
    name='Uncertainty'
))

# Define all spectral features with different categories (edit here)
features = {
    'PAHs': {
         'PAH 7.7': 7.7, 'PAH 8.6': 8.6, 'PAH 11.3': 11.3,
    },
    'Iron': {
        
    },
    'Neon': {
         '[Ne VI]': 7.65,
    },
    'Other': {
         '[Ar III]': 8.991, 
        '[S IV]': 10.51
    },
    'H₂': {
         'S(3)': 9.66,
        'S(4)': 8.03
    }
}

# Add all features with different colors and styles
colors = {
    'PAHs': '#FF7F0E',  # Orange
    'Iron': '#2CA02C',  # Green
    'Neon': '#D62728',  # Red
    'Other': '#9467BD',  # Purple
    'H₂': '#8C564B'     # Brown
}

# Add vertical lines and annotations
for category, lines in features.items():
    for name, wl in lines.items():
        fig.add_vline(
            x=wl,
            line=dict(
                color=colors[category],
                width=1.5 if category == 'PAHs' else 1,
                dash='dot' if category != 'PAHs' else 'solid'
            ),
            annotation=dict(
                text=name,
                yanchor='bottom',
                font=dict(
                    size=10,
                    color=colors[category]
                ),
                yshift=10 if category == 'PAHs' else 0
            )
        )

# Highlight PAH bands with shaded regions
for wl in [ 7.7, 8.6, 11.3]:  # Add the PAH bands you want to highlight
    # Add a shaded rectangle for each PAH band
    # The rectangle is centered around the wavelength with a width of 0.3 microns
    fig.add_vrect(
        x0=wl-0.15, x1=wl+0.15,
        fillcolor=colors['PAHs'],
        opacity=0.1,
        line_width=0
    )

# Customize layout
fig.update_layout(
    # Title and axis labels
    title='<b>NGC 7469 JWST/MIRI IFU Spectrum with Molecular and Atomic Features</b>',
    xaxis_title='<b>Wavelength (μm)</b>',
    yaxis_title='<b>Intensity (MJy/sr)</b>',
    hovermode='x unified',                    # Unified hover mode for better interaction
    legend=dict(                              # Position the legend outside the plot area
        orientation='h',
        yanchor='bottom',
        y=1.02,
        xanchor='right',
        x=1
    ),
    margin=dict(l=50, r=50, b=50, t=80),      # Adjust margins for better spacing
)

fig.show()

# %% [markdown]
# ## Using Cubeviz locally in your system

# %% [markdown]
# You can try installing jdaviz and do the analysis locally in your system. You can best use it in jupyter lab.

# %%
# %pip install jdaviz
# Out:
# Requirement already satisfied: jdaviz in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (4.2.1)
# Requirement already satisfied: packaging in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (24.2)
# Requirement already satisfied: astropy>=6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (7.0.1)
# Requirement already satisfied: matplotlib>=3.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (3.10.1)
# Requirement already satisfied: traitlets>=5.0.5 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (5.14.3)
# Requirement already satisfied: bqplot>=0.12.37 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.12.44)
# Requirement already satisfied: glue-core>=1.22.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.22.0)
# Requirement already satisfied: glue-jupyter>=0.23.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.23.1)
# Requirement already satisfied: echo>=0.5.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.9.0)
# Requirement already satisfied: ipykernel>=6.19.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (6.29.5)
# Requirement already satisfied: ipyvue>=1.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.11.2)
# Requirement already satisfied: ipyvuetify>=1.7.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.11.1)
# Requirement already satisfied: ipysplitpanes>=0.1.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.2.0)
# Requirement already satisfied: ipygoldenlayout>=0.3.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.4.0)
# Requirement already satisfied: ipywidgets>=8.0.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (8.1.5)
# Requirement already satisfied: solara>=1.40.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.44.1)
# Requirement already satisfied: pyyaml>=5.4.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (6.0.2)
# Requirement already satisfied: specutils>=1.18 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.19.0)
# Requirement already satisfied: specreduce<1.5,>=1.4.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.4.1)
# Requirement already satisfied: photutils>=1.12.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (2.2.0)
# Requirement already satisfied: glue-astronomy>=0.10 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.10.0)
# Requirement already satisfied: asteval>=0.9.23 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.0.6)
# Requirement already satisfied: idna in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (3.10)
# Requirement already satisfied: vispy>=0.6.5 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.14.3)
# Requirement already satisfied: asdf>=2.14.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (4.1.0)
# Requirement already satisfied: stdatamodels>=1.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (3.0.1)
# Requirement already satisfied: gwcs>=0.16.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.24.0)
# Requirement already satisfied: regions>=0.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.10)
# Requirement already satisfied: scikit-image in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.25.2)
# Requirement already satisfied: sidecar>=0.5.2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.7.0)
# Requirement already satisfied: ipypopout>=2.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (2.0.0)
# Requirement already satisfied: astroquery in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (0.4.10)
# Requirement already satisfied: requests in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (2.32.3)
# Requirement already satisfied: nbclassic in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.2.0)
# Requirement already satisfied: pyvo>=1.5.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jdaviz) (1.6.1)
# Requirement already satisfied: asdf-standard>=1.1.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf>=2.14.3->jdaviz) (1.1.1)
# Requirement already satisfied: asdf-transform-schemas>=0.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf>=2.14.3->jdaviz) (0.5.0)
# Requirement already satisfied: jmespath>=0.6.2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf>=2.14.3->jdaviz) (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf>=2.14.3->jdaviz) (2.2.4)
# Requirement already satisfied: semantic_version>=2.8 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf>=2.14.3->jdaviz) (2.10.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf>=2.14.3->jdaviz) (25.3.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from astropy>=6->jdaviz) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from astropy>=6->jdaviz) (0.2025.3.24.0.35.32)
# Requirement already satisfied: traittypes>=0.0.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from bqplot>=0.12.37->jdaviz) (0.2.1)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from bqplot>=0.12.37->jdaviz) (2.2.3)
# Requirement already satisfied: spectral-cube>=0.6.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-astronomy>=0.10->jdaviz) (0.6.6)
# Requirement already satisfied: scipy>=1.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (1.15.2)
# Requirement already satisfied: fast_histogram>=0.12 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (0.14)
# Requirement already satisfied: ipython>=4.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (9.0.2)
# Requirement already satisfied: dill>=0.2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (0.3.9)
# Requirement already satisfied: xlrd>=1.2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (2.0.1)
# Requirement already satisfied: openpyxl>=3.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (3.1.5)
# Requirement already satisfied: mpl-scatter-density>=0.8 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (0.8)
# Requirement already satisfied: shapely>=2.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-core>=1.22.0->jdaviz) (2.0.7)
# Requirement already satisfied: glue-vispy-viewers>=1.2.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-vispy-viewers[jupyter]>=1.2.1->glue-jupyter>=0.23.0->jdaviz) (1.2.2)
# Requirement already satisfied: notebook>=4.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-jupyter>=0.23.0->jdaviz) (7.3.3)
# Requirement already satisfied: ipympl>=0.3.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-jupyter>=0.23.0->jdaviz) (0.9.7)
# Requirement already satisfied: ipyvolume>=0.5.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-jupyter>=0.23.0->jdaviz) (0.6.3)
# Requirement already satisfied: bqplot-image-gl>=1.5.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-jupyter>=0.23.0->jdaviz) (1.6.1)
# Requirement already satisfied: bqplot-gl in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-jupyter>=0.23.0->jdaviz) (0.0.0)
# Requirement already satisfied: asdf_wcs_schemas>=0.4.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from gwcs>=0.16.1->jdaviz) (0.4.0)
# Requirement already satisfied: asdf-astropy>=0.5.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from gwcs>=0.16.1->jdaviz) (0.7.1)
# Requirement already satisfied: appnope in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (1.8.13)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (1.6.0)
# Requirement already satisfied: psutil in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (26.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipykernel>=6.19.4->jdaviz) (6.4.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipywidgets>=8.0.6->jdaviz) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipywidgets>=8.0.6->jdaviz) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from matplotlib>=3.6->jdaviz) (2.9.0.post0)
# Requirement already satisfied: solara-server==1.44.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (1.44.1)
# Requirement already satisfied: solara-ui==1.44.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (1.44.1)
# Requirement already satisfied: click>=7.1.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (8.1.8)
# Requirement already satisfied: filelock in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (3.18.0)
# Requirement already satisfied: jinja2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (3.1.6)
# Requirement already satisfied: nbformat in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (5.10.4)
# Requirement already satisfied: rich-click in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (1.8.8)
# Requirement already satisfied: watchdog in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (6.0.0)
# Requirement already satisfied: watchfiles in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (1.0.4)
# Requirement already satisfied: starlette in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (0.46.1)
# Requirement already satisfied: uvicorn in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (0.34.0)
# Requirement already satisfied: websockets in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (15.0.1)
# Requirement already satisfied: humanize in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (4.12.2)
# Requirement already satisfied: reacton>=1.9 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (1.9.1)
# Requirement already satisfied: cachetools in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (5.5.2)
# Requirement already satisfied: markdown in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (3.7)
# Requirement already satisfied: pygments in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (2.19.1)
# Requirement already satisfied: pymdown-extensions in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from solara-ui[all]==1.44.1->solara>=1.40.0->jdaviz) (10.14.3)
# Requirement already satisfied: ndcube>=2.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from specutils>=1.18->jdaviz) (2.3.1)
# Requirement already satisfied: freetype-py in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from vispy>=0.6.5->jdaviz) (2.5.1)
# Requirement already satisfied: hsluv in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from vispy>=0.6.5->jdaviz) (5.0.4)
# Requirement already satisfied: beautifulsoup4>=4.8 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from astroquery->jdaviz) (4.13.3)
# Requirement already satisfied: html5lib>=0.999 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from astroquery->jdaviz) (1.1)
# Requirement already satisfied: keyring>=15.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from astroquery->jdaviz) (25.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from requests->jdaviz) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from requests->jdaviz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from requests->jdaviz) (2025.1.31)
# Requirement already satisfied: ipython-genutils in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbclassic->jdaviz) (0.2.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbclassic->jdaviz) (0.2.4)
# Requirement already satisfied: networkx>=3.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from scikit-image->jdaviz) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from scikit-image->jdaviz) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from scikit-image->jdaviz) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from scikit-image->jdaviz) (0.4)
# Requirement already satisfied: asdf-coordinates-schemas>=0.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from asdf-astropy>=0.5.0->gwcs>=0.16.1->jdaviz) (0.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from beautifulsoup4>=4.8->astroquery->jdaviz) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from beautifulsoup4>=4.8->astroquery->jdaviz) (4.13.0)
# Requirement already satisfied: pyopengl in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-vispy-viewers>=1.2.1->glue-vispy-viewers[jupyter]>=1.2.1->glue-jupyter>=0.23.0->jdaviz) (3.1.9)
# Requirement already satisfied: glfw in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-vispy-viewers>=1.2.1->glue-vispy-viewers[jupyter]>=1.2.1->glue-jupyter>=0.23.0->jdaviz) (2.8.0)
# Requirement already satisfied: jupyter-rfb in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from glue-vispy-viewers[jupyter]>=1.2.1->glue-jupyter>=0.23.0->jdaviz) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from html5lib>=0.999->astroquery->jdaviz) (1.17.0)
# Requirement already satisfied: webencodings in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from html5lib>=0.999->astroquery->jdaviz) (0.5.1)
# Requirement already satisfied: decorator in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipython>=4.0->glue-core>=1.22.0->jdaviz) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipython>=4.0->glue-core>=1.22.0->jdaviz) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipython>=4.0->glue-core>=1.22.0->jdaviz) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipython>=4.0->glue-core>=1.22.0->jdaviz) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipython>=4.0->glue-core>=1.22.0->jdaviz) (3.0.50)
# Requirement already satisfied: stack_data in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipython>=4.0->glue-core>=1.22.0->jdaviz) (0.6.3)
# Requirement already satisfied: ipywebrtc in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipyvolume>=0.5.0->glue-jupyter>=0.23.0->jdaviz) (0.6.0)
# Requirement already satisfied: pythreejs>=2.4.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from ipyvolume>=0.5.0->glue-jupyter>=0.23.0->jdaviz) (2.4.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.19.4->jdaviz) (4.3.7)
# Requirement already satisfied: jaraco.classes in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from keyring>=15.0->astroquery->jdaviz) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from keyring>=15.0->astroquery->jdaviz) (4.1.0)
# Requirement already satisfied: jaraco.context in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from keyring>=15.0->astroquery->jdaviz) (6.0.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (4.3.6)
# Requirement already satisfied: et-xmlfile in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from openpyxl>=3.0->glue-core>=1.22.0->jdaviz) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from pandas<3.0.0,>=1.0.0->bqplot>=0.12.37->jdaviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from pandas<3.0.0,>=1.0.0->bqplot>=0.12.37->jdaviz) (2025.2)
# Requirement already satisfied: radio_beam>=0.3.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (0.3.8)
# Requirement already satisfied: dask[array] in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (2025.3.0)
# Requirement already satisfied: joblib in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (1.4.2)
# Requirement already satisfied: casa-formats-io in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (0.3.0)
# Requirement already satisfied: tqdm in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (4.67.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jedi>=0.16->ipython>=4.0->glue-core>=1.22.0->jdaviz) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (7.16.6)
# Requirement already satisfied: overrides>=5.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jinja2->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (3.0.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab<4.4,>=4.3.6->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (72.1.0)
# Requirement already satisfied: babel>=2.10 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbformat->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from pexpect>4.3->ipython>=4.0->glue-core>=1.22.0->jdaviz) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0->glue-core>=1.22.0->jdaviz) (0.2.13)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from pythreejs>=2.4.0->ipyvolume>=0.5.0->glue-jupyter>=0.23.0->jdaviz) (4.3.5)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (1.0.0)
# Requirement already satisfied: more-itertools in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jaraco.classes->keyring>=15.0->astroquery->jdaviz) (10.6.0)
# Requirement already satisfied: rich>=10.7 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from rich-click->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (13.9.4)
# Requirement already satisfied: executing>=1.2.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from stack_data->ipython>=4.0->glue-core>=1.22.0->jdaviz) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from stack_data->ipython>=4.0->glue-core>=1.22.0->jdaviz) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from stack_data->ipython>=4.0->glue-core>=1.22.0->jdaviz) (0.2.3)
# Requirement already satisfied: h11>=0.8 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from uvicorn->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.0.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.1.1)
# Requirement already satisfied: bleach!=5.0.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.5.1)
# Requirement already satisfied: locket in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from partd>=1.4.0->dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.10->jdaviz) (1.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from rich>=10.7->rich-click->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (3.0.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.4.0)
# Requirement already satisfied: fqdn in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.5.1)
# Requirement already satisfied: isoduration in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (3.0.0)
# Requirement already satisfied: uri-template in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara>=1.40.0->jdaviz) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.17.1)
# Requirement already satisfied: pycparser in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/supersatya/miniconda3/envs/jdaviz_env/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0->glue-jupyter>=0.23.0->jdaviz) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Channel 3 opened in Cubeviz
from jdaviz import Cubeviz

cubeviz = Cubeviz()

# load the dataset:
cubeviz.load_data('./MAST_NGC_7469/jw01328-c1006_t014_miri_ch2-long_s3d.fits')  # Give the path to your FITS file here

# Show the Cubeviz interface
# You can interact with the data, plot spectra, and analyze the cube
# Note: Make sure you have the jdaviz package installed in your environment
cubeviz.show()
# Out:
# Application(config='cubeviz', docs_link='https://jdaviz.readthedocs.io/en/v4.2.1/cubeviz/index.html', events=[…
